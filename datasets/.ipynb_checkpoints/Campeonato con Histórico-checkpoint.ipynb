# %% [markdown]
# # Comparación del rendimiento de los diferentes escaladores
# ## Prueba 1 - Un único campeonato
#
# Es un pequeño experimento, no vamos a entrar en detalle. Extender si acierto.

# %%
# Importamos librerias, pandas para manejo de datos, json y urllib
# para descargar los dataset de la IFSC

import pandas as pd
import urllib.request, json

# %%
# Descargamos dataset del campeonato a evaluar
url = "https://ifsc.egroupware.net/egw/ranking/json.php?comp=8322" 

with urllib.request.urlopen(url) as url:
    data = json.loads(url.read().decode())

# %%
pd.io.json.json_normalize(data)
# Out:
#   WetId                                               name   rkey  \
# 0  8322  IFSC Combined Qualifier - Toulouse/Tournefeuil...  19_W2
#
#   display_athlete duration    date_end                      date_span  \
# 0          nation        4  2019-12-01  28 November - 1 December 2019
#
#          date                                          categorys  \
# 0  2019-11-28  [{'GrpId': '42', 'name': 'WOMEN combined', 'rk...
#
#                                         competitions  expires  \
# 0  [{'WetId': '8322', 'name': 'IFSC Combined Qual...      300
#
#                                  etag
# 0  "db6096fb2e036b1973928b8c6847842c"

# %%
pd.io.json.json_normalize(data['categorys'])
# Out:
#   GrpId            name    rkey  \
# 0    42  WOMEN combined  ICC_FX
# 1    45    MEN combined  ICC_MX
#
#                                                  url  \
# 0  https://www.ifsc-climbing.org/index.php/world-...
# 1  https://www.ifsc-climbing.org/index.php/world-...
#
#                                              results
# 0  [{'result_rank': '1', 'PerId': '60150', 'first...
# 1  [{'result_rank': '1', 'PerId': '10172', 'first...

# %%
women = pd.io.json.json_normalize(data['categorys'][0]['results'])
women
# Out:
#   result_rank  PerId firstname    lastname birthyear nation fed_id  \
# 0           1  60150    Futaba         Ito      2002    JPN     62
# 1           2   9984     Julia  Chanourdie      1996    FRA      6
# 2           3  13209       Mia      Krampl      2000    SLO     19
# 3           4  13208     Lucka     Rakovec      2001    SLO     19
# 4           5  66821        Ai        Mori      2003    JPN     62
# 5           6  10857    Iuliia     Kaplina      1993    RUS      2
# 6           7  11374      Kyra      Condie      1996    USA     39
# 7           8  13189     Laura      Rogora      2001    ITA     15
#
#                                           federation                  city  \
# 0  Japan Mountaineering & Sport Climbing Association    Morioka-shi, Iwate
# 1  Federation Française de la Montagne et de l'Es...              AVIERNOZ
# 2                     Alpine Association of Slovenia                Golnik
# 3                     Alpine Association of Slovenia             Ljubljana
# 4  Japan Mountaineering & Sport Climbing Association  Tsukuba-shi, Ibaraki
# 5                      Climbing Federation of Russia                Tyumen
# 6                                       USA Climbing             Shoreview
# 7          Federazione Italiana Arrampicata Sportiva                  Roma
#
#                          fed_url  \
# 0  http://www.jma-sangaku.or.jp/
# 1             http://www.ffme.fr
# 2          http://www.pzs.si/ksp
# 3          http://www.pzs.si/ksp
# 4  http://www.jma-sangaku.or.jp/
# 5            http://www.c-f-r.ru
# 6     http://www.usaclimbing.org
# 7      http://www.federclimb.it/
#
#                                                  url
# 0  https://www.ifsc-climbing.org/index.php?option...
# 1  https://www.ifsc-climbing.org/index.php?option...
# 2  https://www.ifsc-climbing.org/index.php?option...
# 3  https://www.ifsc-climbing.org/index.php?option...
# 4  https://www.ifsc-climbing.org/index.php?option...
# 5  https://www.ifsc-climbing.org/index.php?option...
# 6  https://www.ifsc-climbing.org/index.php?option...
# 7  https://www.ifsc-climbing.org/index.php?option...

# %%
men = pd.io.json.json_normalize(data['categorys'][1]['results'])
men
# Out:
#   result_rank  PerId  firstname     lastname birthyear nation fed_id  \
# 0           1  10172     Kokoro        Fujii      1992    JPN     62
# 1           2   8372       Adam        Ondra      1993    CZE     29
# 2           3  12432     Meichi     Narasaki      1999    JPN     62
# 3           4      6      Bassa        Mawem      1984    FRA      6
# 4           5   6623        Jan        Hojer      1992    GER      1
# 5           6  12940      YuFei          Pan      2000    CHN    151
# 6           7  56609    Alberto  Ginés López      2002    ESP     11
# 7           8  12601  Nathaniel      Coleman      1997    USA     39
#
#                                           federation                 city  \
# 0  Japan Mountaineering & Sport Climbing Association        Kiyose,Tokyo
# 1                             Cesky Horolezecky Svaz                 Brno
# 2  Japan Mountaineering & Sport Climbing Association  Utsunomiya, Tochigi
# 3  Federation Française de la Montagne et de l'Es...     Clermont Ferrand
# 4                              Deutscher Alpenverein              Frechen
# 5                 Chinese Mountaineering Association              Beijing
# 6  Federación Española de Deportes de Montaña y E...              Cáceres
# 7                                       USA Climbing               Murray
#
#                          fed_url  \
# 0  http://www.jma-sangaku.or.jp/
# 1        http://www.horosvaz.cz/
# 2  http://www.jma-sangaku.or.jp/
# 3             http://www.ffme.fr
# 4      http://www.alpenverein.de
# 5  http://cmasports.sport.org.cn
# 6            http://www.fedme.es
# 7     http://www.usaclimbing.org
#
#                                                  url
# 0  https://www.ifsc-climbing.org/index.php?option...
# 1  https://www.ifsc-climbing.org/index.php?option...
# 2  https://www.ifsc-climbing.org/index.php?option...
# 3  https://www.ifsc-climbing.org/index.php?option...
# 4  https://www.ifsc-climbing.org/index.php?option...
# 5  https://www.ifsc-climbing.org/index.php?option...
# 6  https://www.ifsc-climbing.org/index.php?option...
# 7  https://www.ifsc-climbing.org/index.php?option...

# %% [markdown]
# ## Comparación entre participantes
#
# Vistos los resultados generales, antes de desglosar por pruebas, vamos a consultar las puntuaciones en otras competiciones por fechas para cada deportista.

# %%
# Descargamos los datos de cada participante en una lista

person = list()
for per in women['PerId']:
    url = "https://ifsc.egroupware.net/egw/ranking/json.php?person=%i" %int(per)
    with urllib.request.urlopen(url) as url:
        person.append(json.loads(url.read().decode()))

# %%
# Reagrupamos en una única matriz
ds = list()
df = pd.DataFrame(columns = ['rank', 'date', 'name', 'url', 'WetId', 'cat_name', 'GrpId', 'PerId'])
for per in person:
    temp = pd.io.json.json_normalize(per['results'])
    temp['rank'] = temp['rank'].astype(int)
    temp['date'] = pd.to_datetime(temp['date'])
    temp['PerId'] = per['PerId']
    ds.append(temp)
df = pd.concat(ds)

# %%
df.set_index('date', inplace=True)
df.groupby('PerId')['rank'].plot()
# Out:
# PerId
# 10857    AxesSubplot(0.125,0.2;0.775x0.68)
# 11374    AxesSubplot(0.125,0.2;0.775x0.68)
# 13189    AxesSubplot(0.125,0.2;0.775x0.68)
# 13208    AxesSubplot(0.125,0.2;0.775x0.68)
# 13209    AxesSubplot(0.125,0.2;0.775x0.68)
# 60150    AxesSubplot(0.125,0.2;0.775x0.68)
# 66821    AxesSubplot(0.125,0.2;0.775x0.68)
# 9984     AxesSubplot(0.125,0.2;0.775x0.68)
# Name: rank, dtype: object

# %%
# Out:
#     rank       date                                               name  \
# 0      1 2019-11-28  IFSC Combined Qualifier - Toulouse/Tournefeuil...
# 1     12 2019-10-26     IFSC Climbing Worldcup (L) - Inzai (JPN) 2019
# 2     23 2019-09-28     IFSC Climbing Worldcup (L) - Kranj (SLO) 2019
# 3      7 2019-08-18  IFSC Climbing World Championships Combined - H...
# 4      7 2019-08-11  IFSC Climbing World Championships - Hachioji (...
# ..   ...        ...                                                ...
# 74     9 2015-07-21  European Youth Championship (B) - L'Argentière...
# 75    12 2015-07-04   European Youth Cup (B) - Laengenfeld (AUT) 2015
# 76     4 2015-06-12  European Youth Championship (L, S) - Edinburgh...
# 77     8 2015-05-30           European Youth Cup (L) - Imst (AUT) 2015
# 78     8 2015-05-09      European Youth Cup (L) - Dornbirn (AUT) 2015
#
#                                                   url WetId  \
# 0   https://www.ifsc-climbing.org/index.php/world-...  8322
# 1   https://www.ifsc-climbing.org/index.php/world-...  7953
# 2   https://www.ifsc-climbing.org/index.php/world-...  7938
# 3   https://www.ifsc-climbing.org/index.php/world-...  8633
# 4   https://www.ifsc-climbing.org/index.php/world-...  8253
# ..                                                ...   ...
# 74  https://www.ifsc-climbing.org/index.php/world-...  1607
# 75  https://www.ifsc-climbing.org/index.php/world-...  1598
# 76  https://www.ifsc-climbing.org/index.php/world-...  1609
# 77  https://www.ifsc-climbing.org/index.php/world-...  1600
# 78  https://www.ifsc-climbing.org/index.php/world-...  1599
#
#                   cat_name GrpId  PerId
# 0           WOMEN combined    42  60150
# 1           W O M E N lead     2  60150
# 2           W O M E N lead     2  60150
# 3           WOMEN combined    42  60150
# 4     W O M E N bouldering     5  60150
# ..                     ...   ...    ...
# 74  female youth B boulder    80  13189
# 75  female youth B boulder    80  13189
# 76     female youth B lead    20  13189
# 77     female youth B lead    20  13189
# 78     female youth B lead    20  13189
#
# [522 rows x 8 columns]
